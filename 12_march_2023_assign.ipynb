# %%
"""Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
of 5 using Python. Interpret the results."""

import scipy.stats as stats

sample_mean = 50
sample_std = 5
sample_size = 500 #(let)

confidence_level = 0.95
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

margin_of_error = z_score * (sample_std / (sample_size ** 0.5))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)

"""confidence interval is (49.56, 50.43), it means that we are 95% confident that the true population mean falls within this range. 
In other words, we can say that the population mean has a 95% probability of being between 49.56 and 50.43, based on the given sample data."""
# Out:
# 95% Confidence Interval: (49.561738729711706, 50.438261270288294)
# 'confidence interval is (49.56, 50.43), it means that we are 95% confident that the true population mean falls within this range. \nIn other words, we can say that the population mean has a 95% probability of being between 49.56 and 50.43, based on the given sample data.'

# %%
"""Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
brown. Use Python to perform the test with a significance level of 0.05."""

import scipy.stats as stats
import numpy as np

observed_counts = np.array([20, 20, 20, 10, 10, 20])  # let assume total number of mms is 100
expected_counts = np.array([0.20, 0.20, 0.20, 0.10, 0.10, 0.20]) * observed_counts.sum() 

chi2_statistic, p_value = stats.chisquare(observed_counts, expected_counts)

significance_level = 0.05
if p_value < significance_level:
    print("Reject the null hypothesis. The distribution of colors does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis. The distribution of colors matches the expected distribution.")
# Out:
# Fail to reject the null hypothesis. The distribution of colors matches the expected distribution.

# %%
"""Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data:
        Group A Group 2

Outcome 1    20 15
Outcome 2    10 25
Outcome 3    15 20
Interpret the results of the test."""

import scipy.stats as stats
import numpy as np

observed_data = np.array([[20, 15],
                          [10, 25],
                          [15, 20]])

chi2_statistic, p_value, _, _ = stats.chi2_contingency(observed_data)

significance_level = 0.05
if p_value < significance_level:
    print("Reject the null hypothesis. There is evidence of an association between the groups and outcomes.")
else:
    print("Fail to reject the null hypothesis. There is no evidence of an association between the groups and outcomes.")
# Out:
# Fail to reject the null hypothesis. There is no evidence of an association between the groups and outcomes.

# %%
"""Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
population who smoke. """

import statsmodels.stats.proportion as proportion

sample_size = 500
smokers = 60

sample_proportion = smokers / sample_size

confidence_interval = proportion.proportion_confint(smokers, sample_size, alpha=0.05, method='normal')

print("95% Confidence Interval:", confidence_interval)

# The confidence interval may look like (0.091, 0.148), indicating that we are 95% confident that the true proportion of 
# individuals who smoke in the population falls between 0.091 and 0.148.
# Out:
# 95% Confidence Interval: (0.09151638887130706, 0.14848361112869293)

# %%
"""Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
of 12 using Python. Interpret the results."""

import scipy.stats as stats

sample_mean = 75
sample_std = 12
sample_size = 500 #(let)

confidence_level = 0.90
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)

margin_of_error = z_score * (sample_std / (sample_size ** 0.5))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)
# Out:
# 95% Confidence Interval: (74.11727891450386, 75.88272108549614)

# %%
"""Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
area corresponding to a chi-square statistic of 15."""

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

df = 10  # degrees of freedom
x = np.linspace(0, 30, 1000)  # range of chi-square values

# Plot the chi-square distribution
plt.plot(x, stats.chi2.pdf(x, df))

# Shade the area corresponding to a chi-square statistic of 15
x_fill = np.linspace(15, 30, 1000)
y_fill = stats.chi2.pdf(x_fill, df)
plt.fill_between(x_fill, y_fill, color='gray', alpha=0.3)

plt.xlabel('Chi-square Value')
plt.ylabel('Probability Density')
plt.title('Chi-square Distribution (Degrees of Freedom = 10)')
plt.show()

# %%
"""Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
prefer Coke.

    Ans: Sample Proportion (p̂) = Number of people who prefer Coke / Sample size = 520 / 1000 = 0.52
         Standard Error (SE) = sqrt((p̂ * (1 - p̂)) / n) = sqrt((0.52 * (1 - 0.52)) / 1000) ≈ 0.0158
         For a 99% confidence level, the critical value (z-score) is approximately 2.576.
         Margin of Error = Critical Value * Standard Error = 2.576 * 0.0158 ≈ 0.0407
         Confidence Interval = Sample Proportion ± Margin of Error = 0.52 ± 0.0407
         Therefore, the 99% confidence interval for the true proportion of people in the population who 
             prefer Coke is approximately (0.4793, 0.5607). 
"""

# %%
"""Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
expected frequencies of a fair coin. Use a significance level of 0.05.

    Ans: Null hypothesis (H0): The observed frequencies match the expected frequencies of a fair coin.
         Alternative hypothesis (H1): The observed frequencies do not match the expected frequencies.
         For a fair coin, the expected frequency of tails would be 50 (50% of 100 flips).
         The remaining flips would be heads, so the expected frequency for heads is 100 - 50 = 50.
            Create a table of observed and expected frequencies:
            Observed: [45, 55] (tails, heads)
            Expected: [50, 50] (tails, heads)
        Chi-square test statistic (χ2) = ∑((Observed - Expected)^2 / Expected)
            χ2 = ((45 - 50)^2 / 50) + ((55 - 50)^2 / 50)
               = 1
        Degrees of freedom = Number of categories - 1 = 2 - 1 = 1
        Using a significance level of 0.05 and 1 degree of freedom, the critical value is approximately 3.841.
        The test statistic (1) is less than the critical value (3.841), so we fail to reject the null hypothesis.
        
"""

# %%
"""Q9. A study was conducted to determine if there is an association between smoking status (smoker or
non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
Conduct a chi-square test for independence to determine if there is a significant association between
smoking status and lung cancer diagnosis.
Lung Cancer: Yes  Lung Cancer: No
Smoker        60 140
Non-smoker    30 170
Use a significance level of 0.05.




    Ans: Null hypothesis (H0): There is no association between smoking status and lung cancer diagnosis.
         Alternative hypothesis (H1): There is an association between smoking status and lung cancer diagnosis.
         Significance level (α) = 0.05

         Calculate the expected frequencies:
            Expected Frequency = (Row Total * Column Total) / Total Sample Size
            Expected Frequency for "Smoker with Lung Cancer" = (200 * 90) / 400 = 45
            Expected Frequency for "Smoker without Lung Cancer" = (200 * 210) / 400 = 105
            Expected Frequency for "Non-smoker with Lung Cancer" = (200 * 90) / 400 = 45
            Expected Frequency for "Non-smoker without Lung Cancer" = (200 * 210) / 400 = 105

        Chi-square test statistic (χ2) = ∑((Observed - Expected)^2 / Expected)
            χ2 = ((60 - 45)^2 / 45) + ((140 - 105)^2 / 105) + ((30 - 45)^2 / 45) + ((170 - 105)^2 / 105)
                = 61.91

        Degrees of freedom = (Number of rows - 1) * (Number of columns - 1) = (2 - 1) * (2 - 1) = 1

        Using a significance level of 0.05 and 1 degree of freedom, the critical value is approximately 3.841.
        
        The test statistic (0) is less than the critical value (3.841), so we fail to reject the null hypothesis.
"""

# %%
"""Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark
chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from
the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the
contingency table below. Conduct a chi-square test for independence to determine if there is a significant
association between chocolate preference and country of origin.

Milk Chocolate Dark Chocolate White Chocolate

U.S. (n=500)        200 150 150
U.K. (n=500)        225 175 100


Use a significance level of 0.01.



    Ans: Null hypothesis (H0): There is no association between chocolate preference and country of origin.
         Alternative hypothesis (H1): There is an association between chocolate preference and country of origin.
    
         Significance level (α) = 0.01

         Calculate the expected frequencies:
           Expected Frequency = (Row Total * Column Total) / Total Sample Size
           Total Sample Size = 500 + 500 = 1000
           Expected Frequency for "U.S. - Milk Chocolate" = (500 * 200) / 1000 = 100
           Expected Frequency for "U.S. - Dark Chocolate" = (500 * 150) / 1000 = 75
           Expected Frequency for "U.S. - White Chocolate" = (500 * 150) / 1000 = 75
           Expected Frequency for "U.K. - Milk Chocolate" = (500 * 225) / 1000 = 112.5
           Expected Frequency for "U.K. - Dark Chocolate" = (500 * 175) / 1000 = 87.5
           Expected Frequency for "U.K. - White Chocolate" = (500 * 100) / 1000 = 50
       Chi-square test statistic (χ2) = ∑((Observed - Expected)^2 / Expected)
            χ2 = ((200 - 100)^2 / 100) + ((150 - 75)^2 / 75) + ((150 - 75)^2 / 75) + ((225 - 112.5)^2 / 112.5) + 
                    ((175 - 87.5)^2 / 87.5) + ((100 - 50)^2 / 50)
               = 500
       Degrees of freedom = (Number of rows - 1) * (Number of columns - 1)
                          = (2 - 1) * (3 - 1)
                          = 2

       Using a significance level of 0.01 and 2 degrees of freedom, the critical value is approximately 9.210.

       The test statistic (500) is greater than the critical value (9.210), so we reject the null hypothesis.

"""

# %%
"""Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
significance level of 0.05.

    Ans: Null hypothesis (H0): The population mean is equal to 70. (μ = 70)
         Alternative hypothesis (H1): The population mean is significantly different from 70. (μ ≠ 70)
   Significance level (α) = 0.05
   
   t = (Sample Mean - Population Mean) / (Sample Standard Deviation / √Sample Size)
       Given:
       Sample Mean (x̄) = 72
       Population Mean (μ) = 70
       Sample Standard Deviation (s) = 10
       Sample Size (n) = 30
   t = (72 - 70) / (10 / √30) ≈ 2.16
   
   Degrees of freedom (df) = Sample Size - 1 = 30 - 1 = 29

   Using a t-distribution table or statistical software, the critical values are approximately -2.045 and 2.045.

    |2.16| > 2.045, so we reject the null hypothesis.

"""
